# %%
#naive forecast to provide baseline
#Ellis, C.M. (n.d). Store Sales - Time Series Forecasting: Store Sales: Naive on-day model.  Kaggle.
#https://www.kaggle.com/code/carlmcbrideellis/store-sales-naive-one-day-model

#import pandas library for data analysis & manipulation
import pandas as pd

#set file path names for data sources, Kaggle prediction competition provides seven sources 
#https://www.kaggle.com/competitions/store-sales-time-series-forecasting 

#training data for model
train_path = "***\\Project_Data\\train.csv.zip"
#test data for prediction model
test_path = "***\\Project_Data\\test.csv"
#output path
forecast_path = "***\\Project_Models\\naive\\submission.csv"

#import data into pandas dataframe
train_data = pd.read_csv(train_path,compression="zip")
test_data = pd.read_csv(test_path)
                            
#check number of rows & columns in each set
print("training set",train_data.shape)
print("testing set", test_data.shape)
# Out:
# training set (3000888, 6)
# testing set (28512, 5)

# %%
#set date as date type
train_data["date"] = pd.to_datetime(train_data["date"],errors='coerce')
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         datetime64[ns]
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 137.4+ MB

# %%
#set date as date type
test_data["date"] = pd.to_datetime(test_data["date"],errors='coerce')
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28512 non-null  int64
#  1   date         28512 non-null  datetime64[ns]
#  2   store_nbr    28512 non-null  int64
#  3   family       28512 non-null  object
#  4   onpromotion  28512 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
#review date range of train & test date
print("training set date range:", train_data["date"].min(), " to ", train_data["date"].max())
print("testing set date range:", test_data["date"].min(), " to ", test_data["date"].max())
# Out:
# training set date range: 2013-01-01 00:00:00  to  2017-08-15 00:00:00
# testing set date range: 2017-08-16 00:00:00  to  2017-08-31 00:00:00

# %%
#naive forecast assumes last value will continue into future
last_day = train_data.query("date == '2017-08-15' ").reset_index(drop = True)

# %%
#last day in training data
last_day
# Out:
#            id       date  store_nbr                      family     sales  \
# 0     2999106 2017-08-15          1                  AUTOMOTIVE     4.000
# 1     2999107 2017-08-15          1                   BABY CARE     0.000
# 2     2999108 2017-08-15          1                      BEAUTY     4.000
# 3     2999109 2017-08-15          1                   BEVERAGES  1942.000
# 4     2999110 2017-08-15          1                       BOOKS     0.000
# ...       ...        ...        ...                         ...       ...
# 1777  3000883 2017-08-15          9                     POULTRY   438.133
# 1778  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1779  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1780  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1781  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#       onpromotion
# 0               0
# 1               0
# 2               1
# 3              11
# 4               0
# ...           ...
# 1777            0
# 1778            1
# 1779          148
# 1780            8
# 1781            0
#
# [1782 rows x 6 columns]

# %%
#storing in dictionary
last_day_value = last_day.groupby(['store_nbr', 'family'])['sales'].mean().to_dict()

# %%
last_day_value
# Out:
# {(1, 'AUTOMOTIVE'): 4.0,
#  (1, 'BABY CARE'): 0.0,
#  (1, 'BEAUTY'): 4.0,
#  (1, 'BEVERAGES'): 1942.0,
#  (1, 'BOOKS'): 0.0,
#  (1, 'BREAD/BAKERY'): 329.54102,
#  (1, 'CELEBRATION'): 21.0,
#  (1, 'CLEANING'): 703.0,
#  (1, 'DAIRY'): 602.0,
#  (1, 'DELI'): 116.402,
#  (1, 'EGGS'): 131.0,
#  (1, 'FROZEN FOODS'): 89.0,
#  (1, 'GROCERY I'): 2508.0,
#  (1, 'GROCERY II'): 13.0,
#  (1, 'HARDWARE'): 3.0,
#  (1, 'HOME AND KITCHEN I'): 30.0,
#  (1, 'HOME AND KITCHEN II'): 33.0,
#  (1, 'HOME APPLIANCES'): 0.0,
#  (1, 'HOME CARE'): 156.0,
#  (1, 'LADIESWEAR'): 9.0,
#  (1, 'LAWN AND GARDEN'): 17.0,
#  (1, 'LINGERIE'): 4.0,
#  (1, 'LIQUOR,WINE,BEER'): 94.0,
#  (1, 'MAGAZINES'): 3.0,
#  (1, 'MEATS'): 274.176,
#  (1, 'PERSONAL CARE'): 173.0,
#  (1, 'PET SUPPLIES'): 3.0,
#  (1, 'PLAYERS AND ELECTRONICS'): 21.0,
#  (1, 'POULTRY'): 234.892,
#  (1, 'PREPARED FOODS'): 42.822998,
#  (1, 'PRODUCE'): 2240.23,
#  (1, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (1, 'SEAFOOD'): 22.487,
#  (2, 'AUTOMOTIVE'): 2.0,
#  (2, 'BABY CARE'): 0.0,
#  (2, 'BEAUTY'): 9.0,
#  (2, 'BEVERAGES'): 2093.0,
#  (2, 'BOOKS'): 0.0,
#  (2, 'BREAD/BAKERY'): 607.0,
#  (2, 'CELEBRATION'): 8.0,
#  (2, 'CLEANING'): 659.0,
#  (2, 'DAIRY'): 703.0,
#  (2, 'DELI'): 232.882,
#  (2, 'EGGS'): 154.0,
#  (2, 'FROZEN FOODS'): 79.0,
#  (2, 'GROCERY I'): 3212.0,
#  (2, 'GROCERY II'): 21.0,
#  (2, 'HARDWARE'): 1.0,
#  (2, 'HOME AND KITCHEN I'): 19.0,
#  (2, 'HOME AND KITCHEN II'): 26.0,
#  (2, 'HOME APPLIANCES'): 0.0,
#  (2, 'HOME CARE'): 187.0,
#  (2, 'LADIESWEAR'): 15.0,
#  (2, 'LAWN AND GARDEN'): 21.0,
#  (2, 'LINGERIE'): 3.0,
#  (2, 'LIQUOR,WINE,BEER'): 65.0,
#  (2, 'MAGAZINES'): 15.0,
#  (2, 'MEATS'): 357.513,
#  (2, 'PERSONAL CARE'): 202.0,
#  (2, 'PET SUPPLIES'): 3.0,
#  (2, 'PLAYERS AND ELECTRONICS'): 6.0,
#  (2, 'POULTRY'): 365.424,
#  (2, 'PREPARED FOODS'): 90.849,
#  (2, 'PRODUCE'): 2006.874,
#  (2, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (2, 'SEAFOOD'): 32.718002,
#  (3, 'AUTOMOTIVE'): 12.0,
#  (3, 'BABY CARE'): 0.0,
#  (3, 'BEAUTY'): 13.0,
#  (3, 'BEVERAGES'): 6915.0,
#  (3, 'BOOKS'): 0.0,
#  (3, 'BREAD/BAKERY'): 1052.915,
#  (3, 'CELEBRATION'): 31.0,
#  (3, 'CLEANING'): 1627.0,
#  (3, 'DAIRY'): 1832.0,
#  (3, 'DELI'): 299.215,
#  (3, 'EGGS'): 403.0,
#  (3, 'FROZEN FOODS'): 273.655,
#  (3, 'GROCERY I'): 6955.0,
#  (3, 'GROCERY II'): 64.0,
#  (3, 'HARDWARE'): 2.0,
#  (3, 'HOME AND KITCHEN I'): 49.0,
#  (3, 'HOME AND KITCHEN II'): 35.0,
#  (3, 'HOME APPLIANCES'): 0.0,
#  (3, 'HOME CARE'): 423.0,
#  (3, 'LADIESWEAR'): 33.0,
#  (3, 'LAWN AND GARDEN'): 43.0,
#  (3, 'LINGERIE'): 28.0,
#  (3, 'LIQUOR,WINE,BEER'): 184.0,
#  (3, 'MAGAZINES'): 37.0,
#  (3, 'MEATS'): 662.149,
#  (3, 'PERSONAL CARE'): 455.0,
#  (3, 'PET SUPPLIES'): 12.0,
#  (3, 'PLAYERS AND ELECTRONICS'): 30.0,
#  (3, 'POULTRY'): 1155.024,
#  (3, 'PREPARED FOODS'): 222.294,
#  (3, 'PRODUCE'): 7265.289,
#  (3, 'SCHOOL AND OFFICE SUPPLIES'): 1.0,
#  (3, 'SEAFOOD'): 71.061,
#  (4, 'AUTOMOTIVE'): 7.0,
#  (4, 'BABY CARE'): 0.0,
#  (4, 'BEAUTY'): 5.0,
#  (4, 'BEVERAGES'): 1739.0,
#  (4, 'BOOKS'): 0.0,
#  (4, 'BREAD/BAKERY'): 278.259,
#  (4, 'CELEBRATION'): 6.0,
#  (4, 'CLEANING'): 687.0,
#  (4, 'DAIRY'): 568.0,
#  (4, 'DELI'): 178.76,
#  (4, 'EGGS'): 115.0,
#  (4, 'FROZEN FOODS'): 58.838,
#  (4, 'GROCERY I'): 2741.0,
#  (4, 'GROCERY II'): 22.0,
#  (4, 'HARDWARE'): 2.0,
#  (4, 'HOME AND KITCHEN I'): 27.0,
#  (4, 'HOME AND KITCHEN II'): 9.0,
#  (4, 'HOME APPLIANCES'): 0.0,
#  (4, 'HOME CARE'): 179.0,
#  (4, 'LADIESWEAR'): 14.0,
#  (4, 'LAWN AND GARDEN'): 14.0,
#  (4, 'LINGERIE'): 3.0,
#  (4, 'LIQUOR,WINE,BEER'): 59.0,
#  (4, 'MAGAZINES'): 8.0,
#  (4, 'MEATS'): 295.524,
#  (4, 'PERSONAL CARE'): 214.0,
#  (4, 'PET SUPPLIES'): 5.0,
#  (4, 'PLAYERS AND ELECTRONICS'): 5.0,
#  (4, 'POULTRY'): 372.486,
#  (4, 'PREPARED FOODS'): 44.085,
#  (4, 'PRODUCE'): 2031.764,
#  (4, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (4, 'SEAFOOD'): 20.37,
#  (5, 'AUTOMOTIVE'): 9.0,
#  (5, 'BABY CARE'): 0.0,
#  (5, 'BEAUTY'): 7.0,
#  (5, 'BEVERAGES'): 1654.0,
#  (5, 'BOOKS'): 0.0,
#  (5, 'BREAD/BAKERY'): 334.434,
#  (5, 'CELEBRATION'): 28.0,
#  (5, 'CLEANING'): 721.0,
#  (5, 'DAIRY'): 547.0,
#  (5, 'DELI'): 194.971,
#  (5, 'EGGS'): 68.0,
#  (5, 'FROZEN FOODS'): 49.465,
#  (5, 'GROCERY I'): 2696.0,
#  (5, 'GROCERY II'): 21.0,
#  (5, 'HARDWARE'): 0.0,
#  (5, 'HOME AND KITCHEN I'): 26.0,
#  (5, 'HOME AND KITCHEN II'): 15.0,
#  (5, 'HOME APPLIANCES'): 0.0,
#  (5, 'HOME CARE'): 173.0,
#  (5, 'LADIESWEAR'): 14.0,
#  (5, 'LAWN AND GARDEN'): 2.0,
#  (5, 'LINGERIE'): 13.0,
#  (5, 'LIQUOR,WINE,BEER'): 33.0,
#  (5, 'MAGAZINES'): 15.0,
#  (5, 'MEATS'): 226.199,
#  (5, 'PERSONAL CARE'): 183.0,
#  (5, 'PET SUPPLIES'): 4.0,
#  (5, 'PLAYERS AND ELECTRONICS'): 9.0,
#  (5, 'POULTRY'): 241.011,
#  (5, 'PREPARED FOODS'): 52.121,
#  (5, 'PRODUCE'): 1357.823,
#  (5, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (5, 'SEAFOOD'): 9.669,
#  (6, 'AUTOMOTIVE'): 7.0,
#  (6, 'BABY CARE'): 0.0,
#  (6, 'BEAUTY'): 6.0,
#  (6, 'BEVERAGES'): 2678.0,
#  (6, 'BOOKS'): 0.0,
#  (6, 'BREAD/BAKERY'): 499.485,
#  (6, 'CELEBRATION'): 8.0,
#  (6, 'CLEANING'): 1004.0,
#  (6, 'DAIRY'): 845.0,
#  (6, 'DELI'): 328.256,
#  (6, 'EGGS'): 147.0,
#  (6, 'FROZEN FOODS'): 111.0,
#  (6, 'GROCERY I'): 4334.0,
#  (6, 'GROCERY II'): 41.0,
#  (6, 'HARDWARE'): 1.0,
#  (6, 'HOME AND KITCHEN I'): 24.0,
#  (6, 'HOME AND KITCHEN II'): 37.0,
#  (6, 'HOME APPLIANCES'): 0.0,
#  (6, 'HOME CARE'): 258.0,
#  (6, 'LADIESWEAR'): 17.0,
#  (6, 'LAWN AND GARDEN'): 18.0,
#  (6, 'LINGERIE'): 6.0,
#  (6, 'LIQUOR,WINE,BEER'): 56.0,
#  (6, 'MAGAZINES'): 6.0,
#  (6, 'MEATS'): 417.345,
#  (6, 'PERSONAL CARE'): 316.0,
#  (6, 'PET SUPPLIES'): 11.0,
#  (6, 'PLAYERS AND ELECTRONICS'): 15.0,
#  (6, 'POULTRY'): 434.57,
#  (6, 'PREPARED FOODS'): 102.341995,
#  (6, 'PRODUCE'): 2073.636,
#  (6, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (6, 'SEAFOOD'): 47.575,
#  (7, 'AUTOMOTIVE'): 5.0,
#  (7, 'BABY CARE'): 0.0,
#  (7, 'BEAUTY'): 11.0,
#  (7, 'BEVERAGES'): 3999.0,
#  (7, 'BOOKS'): 0.0,
#  (7, 'BREAD/BAKERY'): 659.156,
#  (7, 'CELEBRATION'): 11.0,
#  (7, 'CLEANING'): 1139.0,
#  (7, 'DAIRY'): 1279.0,
#  (7, 'DELI'): 172.975,
#  (7, 'EGGS'): 299.0,
#  (7, 'FROZEN FOODS'): 235.351,
#  (7, 'GROCERY I'): 3678.0,
#  (7, 'GROCERY II'): 33.0,
#  (7, 'HARDWARE'): 1.0,
#  (7, 'HOME AND KITCHEN I'): 42.0,
#  (7, 'HOME AND KITCHEN II'): 44.0,
#  (7, 'HOME APPLIANCES'): 1.0,
#  (7, 'HOME CARE'): 228.0,
#  (7, 'LADIESWEAR'): 21.0,
#  (7, 'LAWN AND GARDEN'): 43.0,
#  (7, 'LINGERIE'): 10.0,
#  (7, 'LIQUOR,WINE,BEER'): 125.0,
#  (7, 'MAGAZINES'): 24.0,
#  (7, 'MEATS'): 500.31198,
#  (7, 'PERSONAL CARE'): 238.0,
#  (7, 'PET SUPPLIES'): 5.0,
#  (7, 'PLAYERS AND ELECTRONICS'): 19.0,
#  (7, 'POULTRY'): 622.673,
#  (7, 'PREPARED FOODS'): 136.361,
#  (7, 'PRODUCE'): 5113.961,
#  (7, 'SCHOOL AND OFFICE SUPPLIES'): 2.0,
#  (7, 'SEAFOOD'): 46.507,
#  (8, 'AUTOMOTIVE'): 4.0,
#  (8, 'BABY CARE'): 1.0,
#  (8, 'BEAUTY'): 8.0,
#  (8, 'BEVERAGES'): 3626.0,
#  (8, 'BOOKS'): 0.0,
#  (8, 'BREAD/BAKERY'): 740.434,
#  (8, 'CELEBRATION'): 13.0,
#  (8, 'CLEANING'): 1198.0,
#  (8, 'DAIRY'): 1330.0,
#  (8, 'DELI'): 276.639,
#  (8, 'EGGS'): 298.0,
#  (8, 'FROZEN FOODS'): 158.993,
#  (8, 'GROCERY I'): 4035.0,
#  (8, 'GROCERY II'): 27.0,
#  (8, 'HARDWARE'): 0.0,
#  (8, 'HOME AND KITCHEN I'): 40.0,
#  (8, 'HOME AND KITCHEN II'): 35.0,
#  (8, 'HOME APPLIANCES'): 0.0,
#  (8, 'HOME CARE'): 321.0,
#  (8, 'LADIESWEAR'): 31.0,
#  (8, 'LAWN AND GARDEN'): 38.0,
#  (8, 'LINGERIE'): 20.0,
#  (8, 'LIQUOR,WINE,BEER'): 142.0,
#  (8, 'MAGAZINES'): 20.0,
#  (8, 'MEATS'): 359.392,
#  (8, 'PERSONAL CARE'): 313.0,
#  (8, 'PET SUPPLIES'): 11.0,
#  (8, 'PLAYERS AND ELECTRONICS'): 22.0,
#  (8, 'POULTRY'): 548.982,
#  (8, 'PREPARED FOODS'): 143.714,
#  (8, 'PRODUCE'): 3939.392,
#  (8, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (8, 'SEAFOOD'): 23.33,
#  (9, 'AUTOMOTIVE'): 15.0,
#  (9, 'BABY CARE'): 0.0,
#  (9, 'BEAUTY'): 10.0,
#  (9, 'BEVERAGES'): 3530.0,
#  (9, 'BOOKS'): 0.0,
#  (9, 'BREAD/BAKERY'): 528.0,
#  (9, 'CELEBRATION'): 16.0,
#  (9, 'CLEANING'): 1439.0,
#  (9, 'DAIRY'): 835.0,
#  (9, 'DELI'): 551.713,
#  (9, 'EGGS'): 244.0,
#  (9, 'FROZEN FOODS'): 133.738,
#  (9, 'GROCERY I'): 6630.383,
#  (9, 'GROCERY II'): 9.0,
#  (9, 'HARDWARE'): 1.0,
#  (9, 'HOME AND KITCHEN I'): 64.0,
#  (9, 'HOME AND KITCHEN II'): 61.0,
#  (9, 'HOME APPLIANCES'): 0.0,
#  (9, 'HOME CARE'): 373.0,
#  (9, 'LADIESWEAR'): 10.0,
#  (9, 'LAWN AND GARDEN'): 11.0,
#  (9, 'LINGERIE'): 6.0,
#  (9, 'LIQUOR,WINE,BEER'): 25.0,
#  (9, 'MAGAZINES'): 11.0,
#  (9, 'MEATS'): 449.228,
#  (9, 'PERSONAL CARE'): 522.0,
#  (9, 'PET SUPPLIES'): 6.0,
#  (9, 'PLAYERS AND ELECTRONICS'): 6.0,
#  (9, 'POULTRY'): 438.133,
#  (9, 'PREPARED FOODS'): 154.553,
#  (9, 'PRODUCE'): 2419.729,
#  (9, 'SCHOOL AND OFFICE SUPPLIES'): 121.0,
#  (9, 'SEAFOOD'): 16.0,
#  (10, 'AUTOMOTIVE'): 4.0,
#  (10, 'BABY CARE'): 0.0,
#  (10, 'BEAUTY'): 4.0,
#  (10, 'BEVERAGES'): 1608.0,
#  (10, 'BOOKS'): 0.0,
#  (10, 'BREAD/BAKERY'): 112.0,
#  (10, 'CELEBRATION'): 2.0,
#  (10, 'CLEANING'): 731.0,
#  (10, 'DAIRY'): 328.0,
#  (10, 'DELI'): 175.0,
#  (10, 'EGGS'): 40.0,
#  (10, 'FROZEN FOODS'): 49.0,
#  (10, 'GROCERY I'): 2679.0,
#  (10, 'GROCERY II'): 5.0,
#  (10, 'HARDWARE'): 1.0,
#  (10, 'HOME AND KITCHEN I'): 5.0,
#  (10, 'HOME AND KITCHEN II'): 12.0,
#  (10, 'HOME APPLIANCES'): 0.0,
#  (10, 'HOME CARE'): 193.0,
#  (10, 'LADIESWEAR'): 13.0,
#  (10, 'LAWN AND GARDEN'): 0.0,
#  (10, 'LINGERIE'): 1.0,
#  (10, 'LIQUOR,WINE,BEER'): 14.0,
#  (10, 'MAGAZINES'): 1.0,
#  (10, 'MEATS'): 235.604,
#  (10, 'PERSONAL CARE'): 176.0,
#  (10, 'PET SUPPLIES'): 2.0,
#  (10, 'PLAYERS AND ELECTRONICS'): 2.0,
#  (10, 'POULTRY'): 102.077,
#  (10, 'PREPARED FOODS'): 26.0,
#  (10, 'PRODUCE'): 256.911,
#  (10, 'SCHOOL AND OFFICE SUPPLIES'): 18.0,
#  (10, 'SEAFOOD'): 11.0,
#  (11, 'AUTOMOTIVE'): 6.0,
#  (11, 'BABY CARE'): 0.0,
#  (11, 'BEAUTY'): 7.0,
#  (11, 'BEVERAGES'): 4128.0,
#  (11, 'BOOKS'): 0.0,
#  (11, 'BREAD/BAKERY'): 2080.0,
#  (11, 'CELEBRATION'): 8.0,
#  (11, 'CLEANING'): 1892.0,
#  (11, 'DAIRY'): 611.0,
#  (11, 'DELI'): 489.812,
#  (11, 'EGGS'): 438.0,
#  (11, 'FROZEN FOODS'): 65.0,
#  (11, 'GROCERY I'): 7209.727,
#  (11, 'GROCERY II'): 14.0,
#  (11, 'HARDWARE'): 1.0,
#  (11, 'HOME AND KITCHEN I'): 23.0,
#  (11, 'HOME AND KITCHEN II'): 14.0,
#  (11, 'HOME APPLIANCES'): 0.0,
#  (11, 'HOME CARE'): 466.0,
#  (11, 'LADIESWEAR'): 16.0,
#  (11, 'LAWN AND GARDEN'): 5.0,
#  (11, 'LINGERIE'): 11.0,
#  (11, 'LIQUOR,WINE,BEER'): 12.0,
#  (11, 'MAGAZINES'): 4.0,
#  (11, 'MEATS'): 829.919,
#  (11, 'PERSONAL CARE'): 401.0,
#  (11, 'PET SUPPLIES'): 0.0,
#  (11, 'PLAYERS AND ELECTRONICS'): 20.0,
#  (11, 'POULTRY'): 526.459,
#  (11, 'PREPARED FOODS'): 111.556,
#  (11, 'PRODUCE'): 2309.767,
#  (11, 'SCHOOL AND OFFICE SUPPLIES'): 25.0,
#  (11, 'SEAFOOD'): 3.0,
#  (12, 'AUTOMOTIVE'): 2.0,
#  (12, 'BABY CARE'): 0.0,
#  (12, 'BEAUTY'): 2.0,
#  (12, 'BEVERAGES'): 1625.0,
#  (12, 'BOOKS'): 0.0,
#  (12, 'BREAD/BAKERY'): 176.0,
#  (12, 'CELEBRATION'): 10.0,
#  (12, 'CLEANING'): 850.0,
#  (12, 'DAIRY'): 373.0,
#  (12, 'DELI'): 145.0,
#  (12, 'EGGS'): 15.0,
#  (12, 'FROZEN FOODS'): 23.0,
#  (12, 'GROCERY I'): 2461.0,
#  (12, 'GROCERY II'): 8.0,
#  (12, 'HARDWARE'): 0.0,
#  (12, 'HOME AND KITCHEN I'): 12.0,
#  (12, 'HOME AND KITCHEN II'): 29.0,
#  (12, 'HOME APPLIANCES'): 0.0,
#  (12, 'HOME CARE'): 143.0,
#  (12, 'LADIESWEAR'): 8.0,
#  (12, 'LAWN AND GARDEN'): 0.0,
#  (12, 'LINGERIE'): 0.0,
#  (12, 'LIQUOR,WINE,BEER'): 22.0,
#  (12, 'MAGAZINES'): 4.0,
#  (12, 'MEATS'): 189.658,
#  (12, 'PERSONAL CARE'): 199.0,
#  (12, 'PET SUPPLIES'): 2.0,
#  (12, 'PLAYERS AND ELECTRONICS'): 6.0,
#  (12, 'POULTRY'): 162.205,
#  (12, 'PREPARED FOODS'): 61.0,
#  (12, 'PRODUCE'): 393.182,
#  (12, 'SCHOOL AND OFFICE SUPPLIES'): 11.0,
#  (12, 'SEAFOOD'): 1.0,
#  (13, 'AUTOMOTIVE'): 4.0,
#  (13, 'BABY CARE'): 0.0,
#  (13, 'BEAUTY'): 4.0,
#  (13, 'BEVERAGES'): 1290.0,
#  (13, 'BOOKS'): 0.0,
#  (13, 'BREAD/BAKERY'): 148.0,
#  (13, 'CELEBRATION'): 3.0,
#  (13, 'CLEANING'): 663.0,
#  (13, 'DAIRY'): 272.0,
#  (13, 'DELI'): 149.0,
#  (13, 'EGGS'): 60.0,
#  (13, 'FROZEN FOODS'): 29.0,
#  (13, 'GROCERY I'): 2748.0,
#  (13, 'GROCERY II'): 1.0,
#  (13, 'HARDWARE'): 0.0,
#  (13, 'HOME AND KITCHEN I'): 12.0,
#  (13, 'HOME AND KITCHEN II'): 9.0,
#  (13, 'HOME APPLIANCES'): 0.0,
#  (13, 'HOME CARE'): 122.0,
#  (13, 'LADIESWEAR'): 1.0,
#  (13, 'LAWN AND GARDEN'): 0.0,
#  (13, 'LINGERIE'): 2.0,
#  (13, 'LIQUOR,WINE,BEER'): 7.0,
#  (13, 'MAGAZINES'): 1.0,
#  (13, 'MEATS'): 187.51201,
#  (13, 'PERSONAL CARE'): 177.0,
#  (13, 'PET SUPPLIES'): 0.0,
#  (13, 'PLAYERS AND ELECTRONICS'): 5.0,
#  (13, 'POULTRY'): 74.084,
#  (13, 'PREPARED FOODS'): 21.0,
#  (13, 'PRODUCE'): 303.455,
#  (13, 'SCHOOL AND OFFICE SUPPLIES'): 7.0,
#  (13, 'SEAFOOD'): 1.0,
#  (14, 'AUTOMOTIVE'): 6.0,
#  (14, 'BABY CARE'): 0.0,
#  (14, 'BEAUTY'): 2.0,
#  (14, 'BEVERAGES'): 2400.0,
#  (14, 'BOOKS'): 0.0,
#  (14, 'BREAD/BAKERY'): 227.0,
#  (14, 'CELEBRATION'): 3.0,
#  (14, 'CLEANING'): 821.0,
#  (14, 'DAIRY'): 436.0,
#  (14, 'DELI'): 256.0,
#  (14, 'EGGS'): 35.0,
#  (14, 'FROZEN FOODS'): 34.0,
#  (14, 'GROCERY I'): 3789.0,
#  (14, 'GROCERY II'): 2.0,
#  (14, 'HARDWARE'): 0.0,
#  (14, 'HOME AND KITCHEN I'): 2.0,
#  (14, 'HOME AND KITCHEN II'): 19.0,
#  (14, 'HOME APPLIANCES'): 0.0,
#  (14, 'HOME CARE'): 166.0,
#  (14, 'LADIESWEAR'): 0.0,
#  (14, 'LAWN AND GARDEN'): 0.0,
#  (14, 'LINGERIE'): 7.0,
#  (14, 'LIQUOR,WINE,BEER'): 19.0,
#  (14, 'MAGAZINES'): 5.0,
#  (14, 'MEATS'): 116.747,
#  (14, 'PERSONAL CARE'): 264.0,
#  (14, 'PET SUPPLIES'): 1.0,
#  (14, 'PLAYERS AND ELECTRONICS'): 13.0,
#  (14, 'POULTRY'): 50.337,
#  (14, 'PREPARED FOODS'): 107.0,
#  (14, 'PRODUCE'): 551.648,
#  (14, 'SCHOOL AND OFFICE SUPPLIES'): 4.0,
#  (14, 'SEAFOOD'): 6.0,
#  (15, 'AUTOMOTIVE'): 3.0,
#  (15, 'BABY CARE'): 1.0,
#  (15, 'BEAUTY'): 6.0,
#  (15, 'BEVERAGES'): 1825.0,
#  (15, 'BOOKS'): 0.0,
#  (15, 'BREAD/BAKERY'): 187.0,
#  (15, 'CELEBRATION'): 2.0,
#  (15, 'CLEANING'): 694.0,
#  (15, 'DAIRY'): 358.0,
#  (15, 'DELI'): 255.0,
#  (15, 'EGGS'): 90.0,
#  (15, 'FROZEN FOODS'): 54.0,
#  (15, 'GROCERY I'): 2628.0,
#  (15, 'GROCERY II'): 7.0,
#  (15, 'HARDWARE'): 1.0,
#  (15, 'HOME AND KITCHEN I'): 15.0,
#  (15, 'HOME AND KITCHEN II'): 13.0,
#  (15, 'HOME APPLIANCES'): 0.0,
#  (15, 'HOME CARE'): 185.0,
#  (15, 'LADIESWEAR'): 7.0,
#  (15, 'LAWN AND GARDEN'): 0.0,
#  (15, 'LINGERIE'): 8.0,
#  (15, 'LIQUOR,WINE,BEER'): 15.0,
#  (15, 'MAGAZINES'): 1.0,
#  (15, 'MEATS'): 180.437,
#  (15, 'PERSONAL CARE'): 161.0,
#  (15, 'PET SUPPLIES'): 1.0,
#  (15, 'PLAYERS AND ELECTRONICS'): 5.0,
#  (15, 'POULTRY'): 128.693,
#  (15, 'PREPARED FOODS'): 61.0,
#  (15, 'PRODUCE'): 1047.301,
#  (15, 'SCHOOL AND OFFICE SUPPLIES'): 3.0,
#  (15, 'SEAFOOD'): 4.0,
#  (16, 'AUTOMOTIVE'): 5.0,
#  (16, 'BABY CARE'): 0.0,
#  (16, 'BEAUTY'): 0.0,
#  (16, 'BEVERAGES'): 1702.0,
#  (16, 'BOOKS'): 0.0,
#  (16, 'BREAD/BAKERY'): 205.0,
#  (16, 'CELEBRATION'): 3.0,
#  (16, 'CLEANING'): 1206.0,
#  (16, 'DAIRY'): 268.0,
#  (16, 'DELI'): 195.0,
#  (16, 'EGGS'): 102.0,
#  (16, 'FROZEN FOODS'): 28.0,
#  (16, 'GROCERY I'): 2372.0,
#  (16, 'GROCERY II'): 4.0,
#  (16, 'HARDWARE'): 0.0,
#  (16, 'HOME AND KITCHEN I'): 12.0,
#  (16, 'HOME AND KITCHEN II'): 16.0,
#  (16, 'HOME APPLIANCES'): 0.0,
#  (16, 'HOME CARE'): 133.0,
#  (16, 'LADIESWEAR'): 0.0,
#  (16, 'LAWN AND GARDEN'): 0.0,
#  (16, 'LINGERIE'): 6.0,
#  (16, 'LIQUOR,WINE,BEER'): 9.0,
#  (16, 'MAGAZINES'): 1.0,
#  (16, 'MEATS'): 77.791,
#  (16, 'PERSONAL CARE'): 119.0,
#  (16, 'PET SUPPLIES'): 0.0,
#  (16, 'PLAYERS AND ELECTRONICS'): 2.0,
#  (16, 'POULTRY'): 64.859,
#  (16, 'PREPARED FOODS'): 41.0,
#  (16, 'PRODUCE'): 913.778,
#  (16, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (16, 'SEAFOOD'): 2.0,
#  (17, 'AUTOMOTIVE'): 9.0,
#  (17, 'BABY CARE'): 0.0,
#  (17, 'BEAUTY'): 2.0,
#  (17, 'BEVERAGES'): 2840.0,
#  (17, 'BOOKS'): 0.0,
#  (17, 'BREAD/BAKERY'): 333.0,
#  (17, 'CELEBRATION'): 6.0,
#  (17, 'CLEANING'): 1175.0,
#  (17, 'DAIRY'): 707.0,
#  (17, 'DELI'): 420.0,
#  (17, 'EGGS'): 213.0,
#  (17, 'FROZEN FOODS'): 140.0,
#  (17, 'GROCERY I'): 4635.0,
#  (17, 'GROCERY II'): 10.0,
#  (17, 'HARDWARE'): 3.0,
#  (17, 'HOME AND KITCHEN I'): 17.0,
#  (17, 'HOME AND KITCHEN II'): 22.0,
#  (17, 'HOME APPLIANCES'): 0.0,
#  (17, 'HOME CARE'): 266.0,
#  (17, 'LADIESWEAR'): 0.0,
#  (17, 'LAWN AND GARDEN'): 0.0,
#  (17, 'LINGERIE'): 3.0,
#  (17, 'LIQUOR,WINE,BEER'): 15.0,
#  (17, 'MAGAZINES'): 5.0,
#  (17, 'MEATS'): 285.509,
#  (17, 'PERSONAL CARE'): 262.0,
#  (17, 'PET SUPPLIES'): 2.0,
#  (17, 'PLAYERS AND ELECTRONICS'): 6.0,
#  (17, 'POULTRY'): 314.182,
#  (17, 'PREPARED FOODS'): 61.0,
#  (17, 'PRODUCE'): 2300.077,
#  (17, 'SCHOOL AND OFFICE SUPPLIES'): 57.0,
#  (17, 'SEAFOOD'): 15.0,
#  (18, 'AUTOMOTIVE'): 1.0,
#  (18, 'BABY CARE'): 4.0,
#  (18, 'BEAUTY'): 7.0,
#  (18, 'BEVERAGES'): 2110.0,
#  (18, 'BOOKS'): 0.0,
#  (18, 'BREAD/BAKERY'): 606.0,
#  (18, 'CELEBRATION'): 13.0,
#  (18, 'CLEANING'): 606.0,
#  (18, 'DAIRY'): 569.0,
#  (18, 'DELI'): 197.847,
#  (18, 'EGGS'): 149.0,
#  (18, 'FROZEN FOODS'): 45.0,
#  (18, 'GROCERY I'): 3024.594,
#  (18, 'GROCERY II'): 8.0,
#  (18, 'HARDWARE'): 1.0,
#  (18, 'HOME AND KITCHEN I'): 11.0,
#  (18, 'HOME AND KITCHEN II'): 28.0,
#  (18, 'HOME APPLIANCES'): 0.0,
#  (18, 'HOME CARE'): 161.0,
#  (18, 'LADIESWEAR'): 4.0,
#  (18, 'LAWN AND GARDEN'): 0.0,
#  (18, 'LINGERIE'): 3.0,
#  (18, 'LIQUOR,WINE,BEER'): 52.0,
#  (18, 'MAGAZINES'): 2.0,
#  (18, 'MEATS'): 84.173004,
#  (18, 'PERSONAL CARE'): 157.0,
#  (18, 'PET SUPPLIES'): 1.0,
#  (18, 'PLAYERS AND ELECTRONICS'): 9.0,
#  (18, 'POULTRY'): 145.543,
#  (18, 'PREPARED FOODS'): 71.548996,
#  (18, 'PRODUCE'): 3164.252,
#  (18, 'SCHOOL AND OFFICE SUPPLIES'): 30.0,
#  (18, 'SEAFOOD'): 21.364,
#  (19, 'AUTOMOTIVE'): 8.0,
#  (19, 'BABY CARE'): 1.0,
#  (19, 'BEAUTY'): 5.0,
#  (19, 'BEVERAGES'): 2537.0,
#  (19, 'BOOKS'): 0.0,
#  (19, 'BREAD/BAKERY'): 197.0,
#  (19, 'CELEBRATION'): 10.0,
#  (19, 'CLEANING'): 952.0,
#  (19, 'DAIRY'): 339.0,
#  (19, 'DELI'): 358.0,
#  (19, 'EGGS'): 57.0,
#  (19, 'FROZEN FOODS'): 33.0,
#  (19, 'GROCERY I'): 3490.0,
#  (19, 'GROCERY II'): 6.0,
#  (19, 'HARDWARE'): 2.0,
#  (19, 'HOME AND KITCHEN I'): 11.0,
#  (19, 'HOME AND KITCHEN II'): 9.0,
#  (19, 'HOME APPLIANCES'): 0.0,
#  (19, 'HOME CARE'): 201.0,
#  (19, 'LADIESWEAR'): 7.0,
#  (19, 'LAWN AND GARDEN'): 0.0,
#  (19, 'LINGERIE'): 9.0,
#  (19, 'LIQUOR,WINE,BEER'): 12.0,
#  (19, 'MAGAZINES'): 10.0,
#  (19, 'MEATS'): 160.44,
#  (19, 'PERSONAL CARE'): 178.0,
#  (19, 'PET SUPPLIES'): 2.0,
#  (19, 'PLAYERS AND ELECTRONICS'): 4.0,
#  (19, 'POULTRY'): 72.127,
#  (19, 'PREPARED FOODS'): 31.0,
#  (19, 'PRODUCE'): 554.62,
#  (19, 'SCHOOL AND OFFICE SUPPLIES'): 14.0,
#  (19, 'SEAFOOD'): 12.0,
#  (20, 'AUTOMOTIVE'): 11.0,
#  (20, 'BABY CARE'): 0.0,
#  (20, 'BEAUTY'): 4.0,
#  (20, 'BEVERAGES'): 4116.0,
#  (20, 'BOOKS'): 0.0,
#  (20, 'BREAD/BAKERY'): 437.0,
#  (20, 'CELEBRATION'): 4.0,
#  (20, 'CLEANING'): 1146.0,
#  (20, 'DAIRY'): 632.0,
#  (20, 'DELI'): 658.019,
#  (20, 'EGGS'): 47.0,
#  (20, 'FROZEN FOODS'): 63.0,
#  (20, 'GROCERY I'): 4792.93,
#  (20, 'GROCERY II'): 9.0,
#  (20, 'HARDWARE'): 0.0,
#  (20, 'HOME AND KITCHEN I'): 15.0,
#  (20, 'HOME AND KITCHEN II'): 16.0,
#  (20, 'HOME APPLIANCES'): 0.0,
#  (20, 'HOME CARE'): 282.0,
#  (20, 'LADIESWEAR'): 0.0,
#  (20, 'LAWN AND GARDEN'): 4.0,
#  (20, 'LINGERIE'): 5.0,
#  (20, 'LIQUOR,WINE,BEER'): 28.0,
#  (20, 'MAGAZINES'): 2.0,
#  (20, 'MEATS'): 329.746,
#  (20, 'PERSONAL CARE'): 349.0,
#  (20, 'PET SUPPLIES'): 0.0,
#  (20, 'PLAYERS AND ELECTRONICS'): 8.0,
#  (20, 'POULTRY'): 273.341,
#  (20, 'PREPARED FOODS'): 66.982,
#  (20, 'PRODUCE'): 1343.671,
#  (20, 'SCHOOL AND OFFICE SUPPLIES'): 92.0,
#  (20, 'SEAFOOD'): 5.0,
#  (21, 'AUTOMOTIVE'): 12.0,
#  (21, 'BABY CARE'): 0.0,
#  (21, 'BEAUTY'): 2.0,
#  (21, 'BEVERAGES'): 3860.0,
#  (21, 'BOOKS'): 0.0,
#  (21, 'BREAD/BAKERY'): 483.0,
#  (21, 'CELEBRATION'): 9.0,
#  (21, 'CLEANING'): 1064.0,
#  (21, 'DAIRY'): 574.0,
#  (21, 'DELI'): 311.309,
#  (21, 'EGGS'): 321.0,
#  (21, 'FROZEN FOODS'): 83.736,
#  (21, 'GROCERY I'): 3965.414,
#  (21, 'GROCERY II'): 13.0,
#  (21, 'HARDWARE'): 0.0,
#  (21, 'HOME AND KITCHEN I'): 50.0,
#  (21, 'HOME AND KITCHEN II'): 21.0,
#  (21, 'HOME APPLIANCES'): 0.0,
#  (21, 'HOME CARE'): 285.0,
#  (21, 'LADIESWEAR'): 5.0,
#  (21, 'LAWN AND GARDEN'): 3.0,
#  (21, 'LINGERIE'): 7.0,
#  (21, 'LIQUOR,WINE,BEER'): 96.0,
#  (21, 'MAGAZINES'): 5.0,
#  (21, 'MEATS'): 112.286,
#  (21, 'PERSONAL CARE'): 236.0,
#  (21, 'PET SUPPLIES'): 3.0,
#  (21, 'PLAYERS AND ELECTRONICS'): 8.0,
#  (21, 'POULTRY'): 138.924,
#  (21, 'PREPARED FOODS'): 135.858,
#  (21, 'PRODUCE'): 2310.433,
#  (21, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (21, 'SEAFOOD'): 3.0,
#  (22, 'AUTOMOTIVE'): 1.0,
#  (22, 'BABY CARE'): 0.0,
#  (22, 'BEAUTY'): 6.0,
#  (22, 'BEVERAGES'): 2193.0,
#  (22, 'BOOKS'): 0.0,
#  (22, 'BREAD/BAKERY'): 122.0,
#  (22, 'CELEBRATION'): 1.0,
#  (22, 'CLEANING'): 581.0,
#  (22, 'DAIRY'): 289.0,
#  (22, 'DELI'): 121.0,
#  (22, 'EGGS'): 95.0,
#  (22, 'FROZEN FOODS'): 55.0,
#  (22, 'GROCERY I'): 2128.0,
#  (22, 'GROCERY II'): 5.0,
#  (22, 'HARDWARE'): 1.0,
#  (22, 'HOME AND KITCHEN I'): 41.0,
#  (22, 'HOME AND KITCHEN II'): 19.0,
#  (22, 'HOME APPLIANCES'): 0.0,
#  (22, 'HOME CARE'): 155.0,
#  (22, 'LADIESWEAR'): 1.0,
#  (22, 'LAWN AND GARDEN'): 0.0,
#  (22, 'LINGERIE'): 4.0,
#  (22, 'LIQUOR,WINE,BEER'): 32.0,
#  (22, 'MAGAZINES'): 4.0,
#  (22, 'MEATS'): 141.749,
#  (22, 'PERSONAL CARE'): 112.0,
#  (22, 'PET SUPPLIES'): 0.0,
#  (22, 'PLAYERS AND ELECTRONICS'): 4.0,
#  (22, 'POULTRY'): 131.07399,
#  (22, 'PREPARED FOODS'): 31.0,
#  (22, 'PRODUCE'): 634.965,
#  (22, 'SCHOOL AND OFFICE SUPPLIES'): 8.0,
#  (22, 'SEAFOOD'): 1.0,
#  (23, 'AUTOMOTIVE'): 1.0,
#  (23, 'BABY CARE'): 0.0,
#  (23, 'BEAUTY'): 3.0,
#  (23, 'BEVERAGES'): 1253.0,
#  (23, 'BOOKS'): 0.0,
#  (23, 'BREAD/BAKERY'): 243.799,
#  (23, 'CELEBRATION'): 11.0,
#  (23, 'CLEANING'): 473.0,
#  (23, 'DAIRY'): 421.0,
#  (23, 'DELI'): 94.624,
#  (23, 'EGGS'): 48.0,
#  (23, 'FROZEN FOODS'): 75.844,
#  (23, 'GROCERY I'): 1816.0,
#  (23, 'GROCERY II'): 25.0,
#  (23, 'HARDWARE'): 0.0,
#  (23, 'HOME AND KITCHEN I'): 11.0,
#  (23, 'HOME AND KITCHEN II'): 20.0,
#  (23, 'HOME APPLIANCES'): 0.0,
#  (23, 'HOME CARE'): 115.0,
#  (23, 'LADIESWEAR'): 19.0,
#  (23, 'LAWN AND GARDEN'): 0.0,
#  (23, 'LINGERIE'): 4.0,
#  (23, 'LIQUOR,WINE,BEER'): 44.0,
#  (23, 'MAGAZINES'): 4.0,
#  (23, 'MEATS'): 918.841,
#  (23, 'PERSONAL CARE'): 140.0,
#  (23, 'PET SUPPLIES'): 5.0,
#  (23, 'PLAYERS AND ELECTRONICS'): 5.0,
#  (23, 'POULTRY'): 439.349,
#  (23, 'PREPARED FOODS'): 22.795,
#  (23, 'PRODUCE'): 1156.31,
#  (23, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (23, 'SEAFOOD'): 2.0,
#  (24, 'AUTOMOTIVE'): 1.0,
#  (24, 'BABY CARE'): 0.0,
#  (24, 'BEAUTY'): 2.0,
#  (24, 'BEVERAGES'): 3118.0,
#  (24, 'BOOKS'): 0.0,
#  (24, 'BREAD/BAKERY'): 720.1,
#  (24, 'CELEBRATION'): 15.0,
#  (24, 'CLEANING'): 1003.0,
#  (24, 'DAIRY'): 1197.0,
#  (24, 'DELI'): 284.71,
#  (24, 'EGGS'): 218.0,
#  (24, 'FROZEN FOODS'): 138.52,
#  (24, 'GROCERY I'): 3739.0,
#  (24, 'GROCERY II'): 32.0,
#  (24, 'HARDWARE'): 2.0,
#  (24, 'HOME AND KITCHEN I'): 19.0,
#  (24, 'HOME AND KITCHEN II'): 39.0,
#  (24, 'HOME APPLIANCES'): 0.0,
#  (24, 'HOME CARE'): 239.0,
#  (24, 'LADIESWEAR'): 2.0,
#  (24, 'LAWN AND GARDEN'): 21.0,
#  (24, 'LINGERIE'): 10.0,
#  (24, 'LIQUOR,WINE,BEER'): 62.0,
#  (24, 'MAGAZINES'): 16.0,
#  (24, 'MEATS'): 397.13,
#  (24, 'PERSONAL CARE'): 257.0,
#  (24, 'PET SUPPLIES'): 22.0,
#  (24, 'PLAYERS AND ELECTRONICS'): 8.0,
#  (24, 'POULTRY'): 513.652,
#  (24, 'PREPARED FOODS'): 103.035995,
#  (24, 'PRODUCE'): 3651.333,
#  (24, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (24, 'SEAFOOD'): 35.914,
#  (25, 'AUTOMOTIVE'): 7.0,
#  (25, 'BABY CARE'): 0.0,
#  (25, 'BEAUTY'): 3.0,
#  (25, 'BEVERAGES'): 1636.0,
#  (25, 'BOOKS'): 0.0,
#  (25, 'BREAD/BAKERY'): 385.94,
#  (25, 'CELEBRATION'): 5.0,
#  (25, 'CLEANING'): 312.0,
#  (25, 'DAIRY'): 484.0,
#  (25, 'DELI'): 102.582,
#  (25, 'EGGS'): 104.0,
#  (25, 'FROZEN FOODS'): 58.0,
#  (25, 'GROCERY I'): 1451.0,
#  (25, 'GROCERY II'): 9.0,
#  (25, 'HARDWARE'): 0.0,
#  (25, 'HOME AND KITCHEN I'): 11.0,
#  (25, 'HOME AND KITCHEN II'): 7.0,
#  (25, 'HOME APPLIANCES'): 0.0,
#  (25, 'HOME CARE'): 72.0,
#  (25, 'LADIESWEAR'): 0.0,
#  (25, 'LAWN AND GARDEN'): 12.0,
#  (25, 'LINGERIE'): 6.0,
#  (25, 'LIQUOR,WINE,BEER'): 96.0,
#  (25, 'MAGAZINES'): 10.0,
#  (25, 'MEATS'): 180.107,
#  (25, 'PERSONAL CARE'): 93.0,
#  (25, 'PET SUPPLIES'): 3.0,
#  (25, 'PLAYERS AND ELECTRONICS'): 3.0,
#  (25, 'POULTRY'): 172.517,
#  (25, 'PREPARED FOODS'): 25.468,
#  (25, 'PRODUCE'): 1269.174,
#  (25, 'SCHOOL AND OFFICE SUPPLIES'): 1.0,
#  (25, 'SEAFOOD'): 4.0,
#  (26, 'AUTOMOTIVE'): 3.0,
#  (26, 'BABY CARE'): 0.0,
#  (26, 'BEAUTY'): 0.0,
#  (26, 'BEVERAGES'): 762.0,
#  (26, 'BOOKS'): 0.0,
#  (26, 'BREAD/BAKERY'): 215.0,
#  (26, 'CELEBRATION'): 4.0,
#  (26, 'CLEANING'): 284.0,
#  (26, 'DAIRY'): 263.0,
#  (26, 'DELI'): 92.42,
#  (26, 'EGGS'): 36.0,
#  (26, 'FROZEN FOODS'): 25.0,
#  (26, 'GROCERY I'): 1100.0,
#  (26, 'GROCERY II'): 3.0,
#  (26, 'HARDWARE'): 0.0,
#  (26, 'HOME AND KITCHEN I'): 12.0,
#  (26, 'HOME AND KITCHEN II'): 6.0,
#  (26, 'HOME APPLIANCES'): 0.0,
#  (26, 'HOME CARE'): 79.0,
#  (26, 'LADIESWEAR'): 0.0,
#  (26, 'LAWN AND GARDEN'): 0.0,
#  (26, 'LINGERIE'): 0.0,
#  (26, 'LIQUOR,WINE,BEER'): 9.0,
#  (26, 'MAGAZINES'): 0.0,
#  (26, 'MEATS'): 165.26,
#  (26, 'PERSONAL CARE'): 118.0,
#  (26, 'PET SUPPLIES'): 2.0,
#  (26, 'PLAYERS AND ELECTRONICS'): 0.0,
#  (26, 'POULTRY'): 118.622,
#  (26, 'PREPARED FOODS'): 18.0,
#  (26, 'PRODUCE'): 377.595,
#  (26, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (26, 'SEAFOOD'): 2.0,
#  (27, 'AUTOMOTIVE'): 5.0,
#  (27, 'BABY CARE'): 1.0,
#  (27, 'BEAUTY'): 3.0,
#  (27, 'BEVERAGES'): 2877.0,
#  (27, 'BOOKS'): 0.0,
#  (27, 'BREAD/BAKERY'): 637.12,
#  (27, 'CELEBRATION'): 16.0,
#  (27, 'CLEANING'): 937.0,
#  (27, 'DAIRY'): 885.0,
#  (27, 'DELI'): 311.631,
#  (27, 'EGGS'): 233.0,
#  (27, 'FROZEN FOODS'): 103.0,
#  (27, 'GROCERY I'): 3731.0,
#  (27, 'GROCERY II'): 37.0,
#  (27, 'HARDWARE'): 7.0,
#  (27, 'HOME AND KITCHEN I'): 19.0,
#  (27, 'HOME AND KITCHEN II'): 21.0,
#  (27, 'HOME APPLIANCES'): 0.0,
#  (27, 'HOME CARE'): 181.0,
#  (27, 'LADIESWEAR'): 7.0,
#  (27, 'LAWN AND GARDEN'): 27.0,
#  (27, 'LINGERIE'): 6.0,
#  (27, 'LIQUOR,WINE,BEER'): 68.0,
#  (27, 'MAGAZINES'): 4.0,
#  (27, 'MEATS'): 245.882,
#  (27, 'PERSONAL CARE'): 239.0,
#  (27, 'PET SUPPLIES'): 14.0,
#  (27, 'PLAYERS AND ELECTRONICS'): 12.0,
#  (27, 'POULTRY'): 382.93,
#  (27, 'PREPARED FOODS'): 89.543,
#  (27, 'PRODUCE'): 2258.659,
#  (27, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (27, 'SEAFOOD'): 19.214,
#  (28, 'AUTOMOTIVE'): 6.0,
#  (28, 'BABY CARE'): 0.0,
#  (28, 'BEAUTY'): 5.0,
#  (28, 'BEVERAGES'): 3660.0,
#  (28, 'BOOKS'): 0.0,
#  (28, 'BREAD/BAKERY'): 685.0,
#  (28, 'CELEBRATION'): 4.0,
#  (28, 'CLEANING'): 1193.0,
#  (28, 'DAIRY'): 1047.0,
#  (28, 'DELI'): 376.378,
#  (28, 'EGGS'): 301.0,
#  (28, 'FROZEN FOODS'): 73.0,
#  (28, 'GROCERY I'): 4808.164,
#  (28, 'GROCERY II'): 21.0,
#  (28, 'HARDWARE'): 0.0,
#  (28, 'HOME AND KITCHEN I'): 38.0,
#  (28, 'HOME AND KITCHEN II'): 13.0,
#  (28, 'HOME APPLIANCES'): 1.0,
#  (28, 'HOME CARE'): 311.0,
#  (28, 'LADIESWEAR'): 0.0,
#  (28, 'LAWN AND GARDEN'): 9.0,
#  (28, 'LINGERIE'): 7.0,
#  (28, 'LIQUOR,WINE,BEER'): 27.0,
#  (28, 'MAGAZINES'): 1.0,
#  (28, 'MEATS'): 249.189,
#  (28, 'PERSONAL CARE'): 420.0,
#  (28, 'PET SUPPLIES'): 3.0,
#  (28, 'PLAYERS AND ELECTRONICS'): 2.0,
#  (28, 'POULTRY'): 194.748,
#  (28, 'PREPARED FOODS'): 87.969,
#  (28, 'PRODUCE'): 3322.75,
#  (28, 'SCHOOL AND OFFICE SUPPLIES'): 1.0,
#  (28, 'SEAFOOD'): 12.0,
#  (29, 'AUTOMOTIVE'): 5.0,
#  (29, 'BABY CARE'): 0.0,
#  (29, 'BEAUTY'): 5.0,
#  (29, 'BEVERAGES'): 3765.0,
#  (29, 'BOOKS'): 0.0,
#  (29, 'BREAD/BAKERY'): 1180.0,
#  (29, 'CELEBRATION'): 13.0,
#  (29, 'CLEANING'): 1071.0,
#  (29, 'DAIRY'): 713.0,
#  (29, 'DELI'): 385.777,
#  (29, 'EGGS'): 292.0,
#  (29, 'FROZEN FOODS'): 74.0,
#  (29, 'GROCERY I'): 4566.328,
#  (29, 'GROCERY II'): 24.0,
#  (29, 'HARDWARE'): 2.0,
#  (29, 'HOME AND KITCHEN I'): 33.0,
#  (29, 'HOME AND KITCHEN II'): 18.0,
#  (29, 'HOME APPLIANCES'): 0.0,
#  (29, 'HOME CARE'): 279.0,
#  (29, 'LADIESWEAR'): 0.0,
#  (29, 'LAWN AND GARDEN'): 6.0,
#  (29, 'LINGERIE'): 3.0,
#  (29, 'LIQUOR,WINE,BEER'): 66.0,
#  (29, 'MAGAZINES'): 4.0,
#  (29, 'MEATS'): 130.392,
#  (29, 'PERSONAL CARE'): 216.0,
#  (29, 'PET SUPPLIES'): 0.0,
#  (29, 'PLAYERS AND ELECTRONICS'): 3.0,
#  (29, 'POULTRY'): 165.984,
#  (29, 'PREPARED FOODS'): 93.841,
#  (29, 'PRODUCE'): 2541.333,
#  (29, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (29, 'SEAFOOD'): 4.0,
#  (30, 'AUTOMOTIVE'): 4.0,
#  (30, 'BABY CARE'): 0.0,
#  (30, 'BEAUTY'): 0.0,
#  (30, 'BEVERAGES'): 4052.0,
#  (30, 'BOOKS'): 0.0,
#  (30, 'BREAD/BAKERY'): 180.0,
#  (30, 'CELEBRATION'): 5.0,
#  (30, 'CLEANING'): 914.0,
#  (30, 'DAIRY'): 308.0,
#  (30, 'DELI'): 166.0,
#  (30, 'EGGS'): 88.0,
#  (30, 'FROZEN FOODS'): 43.0,
#  (30, 'GROCERY I'): 3306.0,
#  (30, 'GROCERY II'): 5.0,
#  (30, 'HARDWARE'): 0.0,
#  (30, 'HOME AND KITCHEN I'): 8.0,
#  (30, 'HOME AND KITCHEN II'): 8.0,
#  (30, 'HOME APPLIANCES'): 0.0,
#  (30, 'HOME CARE'): 152.0,
#  (30, 'LADIESWEAR'): 0.0,
#  (30, 'LAWN AND GARDEN'): 0.0,
#  (30, 'LINGERIE'): 2.0,
#  (30, 'LIQUOR,WINE,BEER'): 8.0,
#  (30, 'MAGAZINES'): 1.0,
#  (30, 'MEATS'): 91.051,
#  (30, 'PERSONAL CARE'): 167.0,
#  (30, 'PET SUPPLIES'): 2.0,
#  (30, 'PLAYERS AND ELECTRONICS'): 6.0,
#  (30, 'POULTRY'): 132.532,
#  (30, 'PREPARED FOODS'): 66.0,
#  (30, 'PRODUCE'): 1263.186,
#  (30, 'SCHOOL AND OFFICE SUPPLIES'): 0.0,
#  (30, 'SEAFOOD'): 5.0,
#  (31, 'AUTOMOTIVE'): 7.0,
#  (31, 'BABY CARE'): 0.0,
#  (31, 'BEAUTY'): 0.0,
#  (31, 'BEVERAGES'): 3981.0,
#  (31, 'BOOKS'): 0.0,
#  (31, 'BREAD/BAKERY'): 700.0,
#  (31, 'CELEBRATION'): 9.0,
#  (31, 'CLEANING'): 994.0,
#  (31, 'DAIRY'): 624.0,
#  (31, 'DELI'): 209.515,
#  ...}

# %%
#applying last day to test set
test_data["sales"]  = test_data.set_index(['store_nbr', 'family']).index.map(last_day_value.get)

# %%
test_data
# Out:
#             id       date  store_nbr                      family  onpromotion  \
# 0      3000888 2017-08-16          1                  AUTOMOTIVE            0
# 1      3000889 2017-08-16          1                   BABY CARE            0
# 2      3000890 2017-08-16          1                      BEAUTY            2
# 3      3000891 2017-08-16          1                   BEVERAGES           20
# 4      3000892 2017-08-16          1                       BOOKS            0
# ...        ...        ...        ...                         ...          ...
# 28507  3029395 2017-08-31          9                     POULTRY            1
# 28508  3029396 2017-08-31          9              PREPARED FOODS            0
# 28509  3029397 2017-08-31          9                     PRODUCE            1
# 28510  3029398 2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399 2017-08-31          9                     SEAFOOD            0
#
#           sales
# 0         4.000
# 1         0.000
# 2         4.000
# 3      1942.000
# 4         0.000
# ...         ...
# 28507   438.133
# 28508   154.553
# 28509  2419.729
# 28510   121.000
# 28511    16.000
#
# [28512 rows x 6 columns]

# %%
#formatting for submission
forecast = pd.DataFrame({"id":test_data.id, "sales": test_data.sales})

# %%
forecast
# Out:
#             id     sales
# 0      3000888     4.000
# 1      3000889     0.000
# 2      3000890     4.000
# 3      3000891  1942.000
# 4      3000892     0.000
# ...        ...       ...
# 28507  3029395   438.133
# 28508  3029396   154.553
# 28509  3029397  2419.729
# 28510  3029398   121.000
# 28511  3029399    16.000
#
# [28512 rows x 2 columns]

# %%
#exporting to csv, excluding index 
forecast.to_csv(forecast_path, index=False)
